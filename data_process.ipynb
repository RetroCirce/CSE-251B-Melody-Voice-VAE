# %%
import numpy as np
from loader import Dataset

# %%
dataset = Dataset(filedir = "data/POP909-Score/")
dataset.split_dataset()
dataset.process(measure_length = 32, min_step = 0.15, process_way = "DYNAMIC_SUB_PRIOR")
print(len(dataset.train_layers))
print(len(dataset.validate_layers))
print(len(dataset.test_layers))
np.save("data/poly_train_dynamic_sub_pr.npy", dataset.train_layers)
np.save("data/poly_validate_dynamic_sub_pr.npy", dataset.validate_layers)
np.save("data/poly_test_dynamic_sub_pr.npy", dataset.test_layers)
# Out:
#   0%|▎                                                                                 | 3/886 [00:00<00:33, 26.38it/s]
# Dataset Init:data/POP909-Score/
# 100%|████████████████████████████████████████████████████████████████████████████████| 886/886 [00:36<00:00, 24.46it/s]
# Dataset Loaded!
# Finish Spliting!
# Measure Time: 4.8
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 3916/3916 [00:16<00:00, 235.43it/s]
# 29249
# 3782
# 3869

# %%
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 886/886 [00:00<00:00, 3483.40it/s]
# max_note: 106 	 min_note: 24

# %%
# Out:
# Finish Spliting!

# %%
# Out:
# Measure Time: 4.8
# 100%|█████████████████████████████████████████████████████████████████████████████| 3916/3916 [00:17<00:00, 217.95it/s]
# True

# %%
# Out:
# 58041

# %%
# Out:
# 7578

# %%
a = np.load("data/poly_train_dynamic.npy", allow_pickle = True)
a[:5]
# Out:
# array([{'raw': [[100, 45, 1.8, 3.75], [100, 52, 2.1, 3.3], [100, 61, 2.4, 3.6], [100, 57, 2.7, 3.6], [100, 64, 3.0, 4.35], [100, 52, 3.3, 3.75], [100, 61, 3.6, 4.2], [100, 57, 3.9, 4.2], [100, 42, 4.2, 4.8], [100, 49, 4.5, 4.8]], 'layers': [[86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 21, 85, 28, 85, 37, 85, 33, 85, 40, 85, 28, 85, 37, 85, 33, 85, 18, 85, 25, 85]]},
# ...

# %%
# Out:
# array([{'raw': [[100, 45, 1.8, 3.75], [100, 52, 2.1, 3.3], [100, 61, 2.4, 3.6], [100, 57, 2.7, 3.6], [100, 64, 3.0, 4.35], [100, 52, 3.3, 3.75], [100, 61, 3.6, 4.2], [100, 57, 3.9, 4.2], [100, 42, 4.2, 4.8], [100, 49, 4.5, 4.8]], 'layers': [[86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 21, 85, 28, 85, 37, 85, 33, 85, 40, 85, 28, 85, 37, 85, 33, 85, 18, 85, 25, 85], [86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 21, 85, 28, 85, 37, 85, 33, 85, 40, 85, 28, 85, 37, 85, 33, 85, 18, 85, 25, 85], [86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 21, 85, 28, 85, 37, 85, 33, 85, 40, 85, 28, 85, 37, 85, 33, 85, 18, 85, 25, 85], [86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 21, 85, 28, 85, 37, 85, 33, 85, 40, 85, 28, 85, 37, 85, 33, 85, 18, 85, 25, 85], [86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 21, 85, 28, 85, 37, 85, 33, 85, 40, 85, 28, 85, 37, 85, 33, 85, 18, 85, 25, 85], [86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 21, 85, 28, 85, 37, 85, 33, 85, 40, 85, 28, 85, 37, 85, 33
# ...

# %%
dataset.get_dataset_info()
