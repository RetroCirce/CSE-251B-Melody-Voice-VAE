# %%
import numpy as np
from loader import Dataset

# %%
dataset = Dataset(filedir = "data/raw/POP909-Score/")
# Out:
# Dataset Init:data/raw/POP909-Score/
# processed: 99
# processed: 199
# processed: 299
# processed: 399
# processed: 499
# processed: 599
# processed: 699
# processed: 799
# Dataset Loaded!

# %%
dataset.split_dataset()
dataset.process(measure_length = 16, min_step = 0.15)
# Out:
# Finish Spliting!
# Measure Time: 2.4
# prcessed: 0
# prcessed: 100
# prcessed: 200
# prcessed: 300
# prcessed: 400
# prcessed: 500
# prcessed: 600
# prcessed: 700
# prcessed: 800
# prcessed: 900
# prcessed: 1000
# prcessed: 1100
# prcessed: 1200
# prcessed: 1300
# prcessed: 1400
# prcessed: 1500
# prcessed: 1600
# prcessed: 1700
# prcessed: 1800
# prcessed: 1900
# prcessed: 2000
# prcessed: 2100
# prcessed: 2200
# prcessed: 2300
# prcessed: 2400
# prcessed: 2500
# prcessed: 2600
# prcessed: 2700
# prcessed: 2800
# prcessed: 2900
# prcessed: 3000
# prcessed: 3100
# prcessed: 3200
# prcessed: 3300
# prcessed: 3400
# prcessed: 3500
# prcessed: 3600
# prcessed: 3700
# prcessed: 3800
# prcessed: 3900
# prcessed: 4000
# prcessed: 4100
# prcessed: 4200
# prcessed: 4300
# prcessed: 4400
# prcessed: 4500
# prcessed: 4600
# prcessed: 4700
# prcessed: 4800
# prcessed: 4900
# prcessed: 5000
# prcessed: 5100
# prcessed: 5200
# prcessed: 5300
# prcessed: 5400
# prcessed: 5500
# prcessed: 5600
# ...

# %%
len(dataset.train_layers)
# Out:
# 58041

# %%
len(dataset.validate_layers)
# Out:
# 7578

# %%
np.save("poly_test.npy", dataset.test_layers)

# %%
a = np.load("poly_train.npy", allow_pickle = True)

# %%
# Out:
# {'raw': [[100, 47, 0.0, 1.95]],
#  'layers': [[47,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    129,
#    129,
#    129],
#   [47,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    129,
#    129,
#    129],
#   [47,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    129,
#    129,
#    129],
#   [47,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    129,
#    129,
#    129],
#   [47,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    129,
#    129,
#    129],
#   [47,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    128,
#    129,
#    129,
# ...
